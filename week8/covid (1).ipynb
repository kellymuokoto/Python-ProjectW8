# %%
import pandas

# %%
import pandas as pd

# %%
df_all = pd.read_csv("owid-covid-data.csv")

# %%
df_all.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df_all.shape
# Out:
# (350085, 67)

# %%
df_all.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df_all.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   16665
# location                                        0
# date                                            0
# total_cases                                 37997
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       337901
# excess_mortality_cumulative                337901
# excess_mortality                           337901
# excess_mortality_cumulative_per_million    337901
# Length: 67, dtype: int64

# %%
print(df_all.columns.tolist())
# Out:
# ['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths', 'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million', 'new_cases_per_million', 'new_cases_smoothed_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients', 'icu_patients_per_million', 'hosp_patients', 'hosp_patients_per_million', 'weekly_icu_admissions', 'weekly_icu_admissions_per_million', 'weekly_hosp_admissions', 'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'total_boosters', 'new_vaccinations', 'new_vaccinations_smoothed', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred', 'tota
# ...

# %%
df = df_all[["date", "location", "total_cases", "total_deaths", "new_cases", "new_deaths", "total_vaccinations", "population"]]

# %%
df.head()
# Out:
#          date     location  total_cases  total_deaths  new_cases  new_deaths  \
# 0  2020-01-03  Afghanistan          NaN           NaN        0.0         0.0
# 1  2020-01-04  Afghanistan          NaN           NaN        0.0         0.0
# 2  2020-01-05  Afghanistan          NaN           NaN        0.0         0.0
# 3  2020-01-06  Afghanistan          NaN           NaN        0.0         0.0
# 4  2020-01-07  Afghanistan          NaN           NaN        0.0         0.0
#
#    total_vaccinations  population
# 0                 NaN  41128772.0
# 1                 NaN  41128772.0
# 2                 NaN  41128772.0
# 3                 NaN  41128772.0
# 4                 NaN  41128772.0

# %%
df_all.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df = df[df["location"].isin(["South Africa", "Zimbabwe", "United States", "India", "Kenya", "Nigeria", "China", "United Kingdom"])]

# %%
df.head()
# Out:
#              date location  total_cases  total_deaths  new_cases  new_deaths  \
# 60962  2020-01-03    China          NaN           NaN        0.0         0.0
# 60963  2020-01-04    China          1.0           NaN        1.0         0.0
# 60964  2020-01-05    China          1.0           NaN        0.0         0.0
# 60965  2020-01-06    China          4.0           NaN        3.0         0.0
# 60966  2020-01-07    China          4.0           NaN        0.0         0.0
#
#        total_vaccinations    population
# 60962                 NaN  1.425887e+09
# 60963                 NaN  1.425887e+09
# 60964                 NaN  1.425887e+09
# 60965                 NaN  1.425887e+09
# 60966                 NaN  1.425887e+09

# %%
df.isnull().sum()
# Out:
# date                     0
# location                 0
# total_cases            348
# total_deaths           481
# new_cases              170
# new_deaths             160
# total_vaccinations    6457
# population               0
# dtype: int64

# %%
df.shape
# Out:
# (11085, 8)

# %%
df.drop_duplicates(inplace=True)

# %%
df = df.dropna(subset=["date", "location", "total_cases", "total_deaths", "new_cases", "new_deaths", "total_vaccinations"])

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.fillna(0, inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="date", y="total_cases", hue="location")
plt.title("Total Cases Over Time")
plt.xlabel("Date")
plt.ylabel("Total Cases")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="date", y="total_deaths", hue="location")
plt.title("Total Deaths Over Time")
plt.xlabel("Date")
plt.ylabel("Total Deaths")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="date", y="new_cases", hue="location")
plt.title("Daily New Cases Comparison")
plt.xlabel("Date")
plt.ylabel("New Cases")
plt.show()

# %%
df["death_rate"] = df["total_deaths"] / df["total_cases"]

plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="date", y="death_rate", hue="location")
plt.title("COVID-19 Death Rate Over Time")
plt.xlabel("Date")
plt.ylabel("Death Rate")
plt.show()

# %%
latest_df = df[df["date"] == df["date"].max()]
top_cases = latest_df.groupby("location")["total_cases"].max().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_cases.index, y=top_cases.values)
plt.title("Top Countries by Total Cases (Latest Date)")
plt.xlabel("Country")
plt.ylabel("Total Cases")
plt.xticks(rotation=45)
plt.show()

# %%
numeric_cols = ["total_cases", "total_deaths", "new_cases", "new_deaths", "death_rate"]
correlation = df[numeric_cols].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="date", y="total_vaccinations", hue="location")
plt.title("Cumulative Vaccinations Over Time")
plt.xlabel("Date")
plt.ylabel("Total Vaccinations")
plt.show()

# %%
vaccinated = df["population"].max()

# %%
df["percent_vaccinated"] = (df["total_vaccinations"] / df["population"]) * 100

# %%
latest = df[df["date"] == df["date"].max()]
percent_data = latest.groupby("location")["percent_vaccinated"].max()

plt.figure(figsize=(10, 6))
sns.barplot(x=percent_data.index, y=percent_data.values)
plt.title("Percent of Population Vaccinated")
plt.xlabel("Country")
plt.ylabel("% Vaccinated")
plt.xticks(rotation=45)
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['date', 'location', 'total_cases', 'total_deaths', 'new_cases', 'new_deaths', 'total_vaccinations', 'population', 'death_rate', 'percent_vaccinated']

# %%
import plotly.express as px


latest_date = df["date"].max()
latest_df = df[df["date"] == latest_date]


map_df = df[[ "location", "total_cases", "total_vaccinations", "population"]].copy()


map_df["cases_per_million"] = (map_df["total_cases"] / map_df["population"]) * 1_000_000
map_df["vaccination_rate"] = (map_df["total_vaccinations"] / map_df["population"]) * 100

# %%
fig = px.choropleth(
    map_df,
    locations="location",
    locationmode="country names",
    color="cases_per_million",
    hover_name="location",
    color_continuous_scale="Reds",
    title="COVID-19 Cases per Million People (Latest Date)"
)
fig.show()

# %%
fig = px.choropleth(
    map_df,
    locations="location",
    locationmode="country names",
    color="vaccination_rate",
    hover_name="location",
    color_continuous_scale="Greens",
    title="COVID-19 Vaccination Rate by Country"
)
fig.show()

# %% [markdown]
# 1. **The United States and India reported the highest total COVID-19 cases** among the selected countries, highlighting the scale of the pandemic in large, populous nations.
#
# 2. **Zimbabwe and Kenya had relatively lower total case counts**, but this may reflect under-testing or reporting limitations rather than true case absence.
#
# 3. **Vaccination rates varied widely**:
#    - **United Kingdom** and **United States** had the highest vaccination coverage.
#    - **Nigeria** and **Zimbabwe** had significantly lower vaccination percentages, pointing to challenges in access or distribution.
#
# 4. **South Africa experienced substantial case surges** during major global waves, indicating higher community spread or better detection compared to neighboring countries.
#
# 5. **China showed lower reported case and death numbers**, which may be due to strict containment policies or underreporting — a topic of debate among global analysts.
